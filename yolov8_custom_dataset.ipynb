# %% [markdown]
# <a href="https://colab.research.google.com/github/l4302/CPE496-Project/blob/main/yolov8_custom_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install ultralytics==8.2.103 -q

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
from ultralytics import YOLO

from IPython.display import display, Image
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 33.2/112.6 GB disk)

# %%
# !yolo task=detect mode=train model=yolov8s.pt data='/content/drive/MyDrive/CPE-496/flower/datasets/data.yaml' epochs=10 imgsz=640 plots=True
# Out:
# New https://pypi.org/project/ultralytics/8.3.78 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.103 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect mode=train model=yolov8m.pt data='/content/drive/MyDrive/CPE-496/flower/datasets/data.yaml' epochs=15 imgsz=640 plots=True
# Out:
# /bin/bash: line 1: yolo: command not found

# %%
Image(filename=f'/content/runs/detect/train4/confusion_matrix.png', width=600)

# %%
Image(filename=f'/content/runs/detect/train4/results.png', width=600)

# %%
Image(filename=f'/content/runs/detect/train4/val_batch0_pred.jpg', width=600)
